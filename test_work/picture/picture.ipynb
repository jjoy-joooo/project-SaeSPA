# %%
# !pip install --upgrade google-cloud-vision
# Out:
# Requirement already satisfied: google-cloud-vision in c:\users\user\miniconda3\envs\saespa\lib\site-packages (3.7.2)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.17.1)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-cloud-vision) (2.28.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-cloud-vision) (1.23.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-cloud-vision) (4.25.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.63.0)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.62.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (1.62.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (4.9)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-vision) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\miniconda3\envs\saespa\lib\site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-vision) (2024.2.2)

# %%
import os

os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = r"C:\Users\USER\Desktop\saespa-32938cc2d664.json"

# %%
import os

# GOOGLE_APPLICATION_CREDENTIALS 환경 변수 값 가져오기
credentials_path = os.getenv('GOOGLE_APPLICATION_CREDENTIALS')

# 환경 변수 값 출력
print('GOOGLE_APPLICATION_CREDENTIALS:', credentials_path)
# Out:
# GOOGLE_APPLICATION_CREDENTIALS: C:\Users\USER\Desktop\saespa-32938cc2d664.json

# %%
from google.cloud import vision
import io

def detect_text(path):
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts:')

    for text in texts:
        print('\n"{}"'.format(text.description))

        vertices = [f'({vertex.x},{vertex.y})' for vertex in text.bounding_poly.vertices]
        print('bounds:', ','.join(vertices))

    if response.error.message:
        raise Exception('{}\nFor more info on error messages, check: https://cloud.google.com/apis/design/errors'.format(response.error.message))

# %%
path = 'C:\\Users\\USER\\Desktop\\data\\ocr\\IMG_6881.jpg'

detect_text(path)
# Out:
# Texts:
#
# "너리를 사용하여 이미지 파일 이름과 해당 텍스트를 출력합니다. 이렇게 하면 각 이미지 파일에 대한
# 추출된 텍스트를 보관할 수 있습니다.
# 혜리 You
# result[O]에서 추출된 글자만 보관
# B
# 0
# ChatGPT
# 이미지에서 추출된 텍스트 중에서 한 글자만을 보관하려면, OCR 결과에서 각 글자의 위치와 텍스트를 확
# 인하고 필요한 정보를 따로 저장해야 합니다. 다음은 해당 작업을 수행하는 방법을 보여주는 코드 예시입
# 니다.
# python
# from paddleocr import PaddleOCR
# import os
# #PaddleOCR 초기화
# ocr = PaddleOCR (lang="korean")
# # 이미지 파일들이 저장된 디렉토리 경로 J
# img_dir = "pic"
# Message ChatGPT.....
# □ Copy code"
# bounds: (462,0),(2702,0),(2702,1745),(462,1745)
#
# "너리"
# bounds: (545,17),(623,16),(624,71),(546,72)
#
# "를"
# bounds: (633,15),(673,15),(674,70),(634,70)
#
# "사용"
# bounds: (688,15),(772,14),(773,69),(689,70)
#
# "하여"
# bounds: (777,14),(861,13),(862,68),(778,69)
#
# "이미지"
# bounds: (881,12),(1009,10),(1010,66),(882,68)
#
# "파일"
# bounds: (1029,11),(1115,10),(1116,65),(1030,66)
#
# "이름"
# bounds: (1134,9),(1220,8),(1221,64),(1135,65)
#
# "과"
# bounds: (1227,8),(1270,7),(1271,62),(1228,63)
#
# "해당"
# bounds: (1284,7),(1374,6),(1375,62),(1285,63)
#
# "텍스트"
# bounds: (1395,6),(1532,4),(1533,60),(1396,62)
#
# "를"
# bounds: (1536,4),(1581,3),(1582,58),(1537,59)
#
# "출력"
# bounds: (1596,4),(1685,3),(1686,58),(1597,59)
#
# "합니다"
# bounds: (1695,2),(1844,0),(1845,56),(1696,58)
#
# "."
# bounds: (1843,1),(1851,1),(1852,56),(1844,56)
#
# "이렇게"
# bounds: (1869,0),(2013,0),(2014,54),(1870,56)
#
# "하면"
# bounds: (2034,0),(2125,0),(2126,54),(2035,55)
#
# "각"
# bounds: (2147,0),(2193,0),(2194,52),(2148,53)
#
# "이미지"
# bounds: (2212,0),(2355,0),(2356,50),(2213,52)
#
# "파일"
# bounds: (2375,0),(2473,0),(2474,49),(2376,50)
#
# "에"
# bounds: (2484,0),(2527,0),(2528,48),(2485,49)
#
# "대한"
# bounds: (2549,0),(2652,0),(2653,47),(2550,48)
#
# "추출"
# bounds: (546,110),(632,109),(633,158),(547,159)
#
# "된"
# bounds: (635,108),(672,108),(673,157),(636,157)
#
# "텍스트"
# bounds: (692,107),(820,105),(821,155),(693,157)
#
# "를"
# bounds: (825,106),(867,105),(868,154),(826,155)
#
# "보관할"
# bounds: (882,105),(1015,103),(1016,153),(883,155)
#
# "수"
# bounds: (1029,103),(1070,102),(1071,151),(1030,152)
#
# "있습니다"
# bounds: (1088,102),(1272,100),(1273,150),(1089,152)
#
# "."
# bounds: (1269,100),(1279,100),(1280,149),(1270,149)
#
# "혜리"
# bounds: (462,347),(510,347),(510,379),(462,379)
#
# "You"
# bounds: (551,346),(623,345),(623,377),(551,378)
#
# "result"
# bounds: (557,410),(665,410),(665,458),(557,458)
#
# "["
# bounds: (669,410),(679,410),(679,458),(669,458)
#
# "O"
# bounds: (681,410),(706,410),(706,458),(681,458)
#
# "]"
# bounds: (706,410),(719,410),(719,458),(706,458)
#
# "에서"
# bounds: (725,410),(804,410),(804,458),(725,458)
#
# "추출"
# bounds: (820,410),(909,410),(909,458),(820,458)
#
# "된"
# bounds: (913,410),(951,410),(951,458),(913,458)
#
# "글자"
# bounds: (967,410),(1056,410),(1056,458),(967,458)
#
# "만"
# bounds: (1061,410),(1101,410),(1101,458),(1061,458)
#
# "보관"
# bounds: (1114,410),(1205,410),(1205,458),(1114,458)
#
# "B"
# bounds: (539,457),(576,477),(558,509),(522,488)
#
# "0"
# bounds: (555,514),(588,500),(599,526),(566,540)
#
# "ChatGPT"
# bounds: (561,632),(742,632),(742,664),(561,664)
#
# "이미지"
# bounds: (568,696),(689,698),(688,751),(567,749)
#
# "에서"
# bounds: (699,699),(775,700),(774,752),(698,751)
#
# "추출"
# bounds: (792,700),(878,702),(877,755),(791,753)
#
# "된"
# bounds: (884,702),(920,703),(919,755),(883,754)
#
# "텍스트"
# bounds: (939,703),(1069,705),(1068,757),(938,755)
#
# "중에서"
# bounds: (1082,706),(1210,708),(1209,760),(1081,758)
#
# "한"
# bounds: (1228,709),(1271,710),(1270,762),(1227,761)
#
# "글자"
# bounds: (1283,710),(1373,712),(1372,764),(1282,762)
#
# "만을"
# bounds: (1377,711),(1465,713),(1464,765),(1376,763)
#
# "보관"
# bounds: (1478,713),(1567,715),(1566,767),(1477,765)
#
# "하려면"
# bounds: (1572,715),(1707,717),(1706,769),(1571,767)
#
# ","
# bounds: (1712,718),(1723,718),(1722,770),(1711,770)
#
# "OCR"
# bounds: (1732,718),(1829,720),(1828,772),(1731,770)
#
# "결과"
# bounds: (1846,720),(1938,722),(1937,774),(1845,772)
#
# "에서"
# bounds: (1944,722),(2031,724),(2030,776),(1943,774)
#
# "각"
# bounds: (2051,724),(2096,725),(2095,777),(2050,776)
#
# "글자"
# bounds: (2110,725),(2208,727),(2207,779),(2109,777)
#
# "의"
# bounds: (2212,727),(2254,728),(2253,780),(2211,779)
#
# "위치"
# bounds: (2274,728),(2367,730),(2366,782),(2273,780)
#
# "와"
# bounds: (2375,730),(2424,731),(2423,783),(2374,782)
#
# "텍스트"
# bounds: (2442,731),(2586,734),(2585,786),(2441,783)
#
# "를"
# bounds: (2592,734),(2639,735),(2638,787),(2591,786)
#
# "확"
# bounds: (2657,735),(2703,736),(2702,788),(2656,787)
#
# "인하"
# bounds: (570,776),(653,778),(652,831),(569,829)
#
# "고"
# bounds: (655,778),(694,779),(693,831),(654,830)
#
# "필요한"
# bounds: (708,780),(837,783),(836,835),(707,832)
#
# "정보"
# bounds: (850,783),(934,785),(933,837),(849,835)
#
# "를"
# bounds: (938,785),(978,786),(977,838),(937,837)
#
# "따로"
# bounds: (995,786),(1077,788),(1076,840),(994,838)
#
# "저장"
# bounds: (1093,788),(1180,790),(1179,842),(1092,840)
#
# "해야"
# bounds: (1183,790),(1270,792),(1269,844),(1182,842)
#
# "합니다"
# bounds: (1283,793),(1418,796),(1417,848),(1282,845)
#
# "."
# bounds: (1418,796),(1429,796),(1428,848),(1417,848)
#
# "다음"
# bounds: (1444,796),(1529,798),(1528,850),(1443,848)
#
# "은"
# bounds: (1534,798),(1576,799),(1575,851),(1533,850)
#
# "해당"
# bounds: (1589,800),(1680,802),(1679,854),(1588,852)
#
# "작업"
# bounds: (1696,802),(1780,804),(1779,856),(1695,854)
#
# "을"
# bounds: (1789,804),(1834,805),(1833,857),(1788,856)
#
# "수행"
# bounds: (1848,805),(1939,807),(1938,859),(1847,857)
#
# "하는"
# bounds: (1946,808),(2039,810),(2038,862),(1945,860)
#
# "방법"
# bounds: (2056,810),(2145,812),(2144,864),(2055,862)
#
# "을"
# bounds: (2154,812),(2199,813),(2198,865),(2153,864)
#
# "보여주는"
# bounds: (2215,814),(2413,818),(2412,870),(2214,866)
#
# "코드"
# bounds: (2428,819),(2524,821),(2523,873),(2427,871)
#
# "예시"
# bounds: (2543,821),(2637,823),(2636,875),(2542,873)
#
# "입"
# bounds: (2647,824),(2686,825),(2685,877),(2646,876)
#
# "니다"
# bounds: (575,859),(655,861),(654,903),(574,901)
#
# "."
# bounds: (656,861),(663,861),(662,903),(655,903)
#
# "python"
# bounds: (617,1013),(719,1014),(719,1044),(617,1043)
#
# "from"
# bounds: (627,1132),(717,1135),(716,1172),(626,1169)
#
# "paddleocr"
# bounds: (737,1136),(945,1144),(943,1181),(736,1173)
#
# "import"
# bounds: (968,1145),(1104,1150),(1103,1186),(967,1181)
#
# "PaddleOCR"
# bounds: (1127,1151),(1340,1159),(1339,1195),(1126,1187)
#
# "import"
# bounds: (624,1199),(758,1205),(756,1238),(622,1232)
#
# "os"
# bounds: (780,1207),(825,1209),(823,1241),(779,1239)
#
# "#PaddleOCR"
# bounds: (624,1325),(874,1337),(872,1374),(622,1362)
#
# "초기화"
# bounds: (898,1338),(1016,1344),(1014,1381),(896,1375)
#
# "ocr"
# bounds: (628,1394),(696,1397),(694,1432),(626,1429)
#
# "="
# bounds: (717,1399),(738,1400),(736,1434),(715,1433)
#
# "PaddleOCR"
# bounds: (762,1401),(966,1410),(964,1444),(760,1435)
#
# "("
# bounds: (968,1410),(983,1411),(981,1445),(966,1444)
#
# "lang"
# bounds: (988,1411),(1077,1415),(1075,1449),(986,1445)
#
# "="
# bounds: (1080,1415),(1100,1416),(1098,1450),(1078,1449)
#
# """
# bounds: (1103,1416),(1121,1417),(1119,1451),(1101,1450)
#
# "korean"
# bounds: (1126,1417),(1262,1423),(1260,1458),(1124,1452)
#
# """
# bounds: (1265,1424),(1283,1425),(1281,1459),(1263,1458)
#
# ")"
# bounds: (1288,1425),(1305,1426),(1303,1460),(1286,1459)
#
# "#"
# bounds: (629,1519),(657,1520),(655,1558),(627,1557)
#
# "이미지"
# bounds: (679,1521),(787,1527),(785,1565),(677,1559)
#
# "파일"
# bounds: (815,1528),(884,1532),(882,1570),(813,1566)
#
# "들이"
# bounds: (891,1532),(960,1536),(958,1575),(889,1571)
#
# "저장된"
# bounds: (990,1538),(1101,1544),(1099,1582),(988,1576)
#
# "디렉토리"
# bounds: (1130,1545),(1278,1553),(1276,1592),(1128,1584)
#
# "경로"
# bounds: (1309,1555),(1388,1559),(1386,1597),(1307,1593)
#
# "J"
# bounds: (1423,1561),(1454,1563),(1452,1601),(1421,1599)
#
# "img_dir"
# bounds: (634,1584),(785,1591),(783,1629),(632,1622)
#
# "="
# bounds: (807,1592),(830,1593),(828,1630),(805,1629)
#
# """
# bounds: (857,1594),(869,1595),(867,1631),(855,1631)
#
# "pic"
# bounds: (878,1595),(940,1598),(938,1635),(876,1632)
#
# """
# bounds: (946,1598),(959,1599),(957,1636),(944,1635)
#
# "Message"
# bounds: (496,1689),(658,1696),(656,1735),(494,1728)
#
# "ChatGPT"
# bounds: (670,1697),(834,1704),(832,1743),(668,1736)
#
# "....."
# bounds: (810,1703),(879,1706),(877,1745),(808,1742)
#
# "□"
# bounds: (2406,1068),(2453,1069),(2452,1108),(2405,1107)
#
# "Copy"
# bounds: (2471,1069),(2561,1072),(2560,1112),(2470,1109)
#
# "code"
# bounds: (2568,1072),(2650,1075),(2649,1115),(2567,1112)
